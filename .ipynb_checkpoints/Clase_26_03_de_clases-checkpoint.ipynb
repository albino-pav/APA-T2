# %%
class ClaseUno:
    """
    Clase para probar cosas de python :)
    """

    atributo = 17

    #metodos
    def metodo_suma(x, y):
        return x+y

# %%
help(ClaseUno)
# Out:
# Help on class ClaseUno in module __main__:
#
# class ClaseUno(builtins.object)
#  |  Clase para probar cosas de python :)
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
