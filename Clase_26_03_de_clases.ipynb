# %%
class ClaseUno:
    """
    Clase para probar cosas de python :)
    """
    #atributos
    atributo = 17
    
    #metodos
    def metodo_suma(mi_mismo, x, y):
        return x+y

# %%
ClaseUno()

# %%
objeto_uno = ClaseUno()

# %%
objeto_uno.metodo_suma(4.,45)
# Out:
# 49.0

# %%
def suma(x, y):
    """
    suma psicodelica
    """

    return x + y

# %%
objeto_uno = ClaseUno()

# %%
objeto_uno.atributo
# Out:
# 17
